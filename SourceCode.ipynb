# %%
#import necessary liberies
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from warnings import simplefilter
simplefilter(action='ignore')

# %%
#unpload dataframe
df=pd.read_csv(r'/content/temp fore - temp (1).csv')

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.tail()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %% [markdown]
# data inspection

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %%
df['Next_Tmax'].value_counts()
# Out:
# Next_Tmax
# 29.3    113
# 33.0    106
# 31.3    104
# 29.6    101
# 31.2     98
#        ...
# 18.6      1
# 19.7      1
# 18.9      1
# 19.5      1
# 21.4      1
# Name: count, Length: 183, dtype: int64

# %%
df['Next_Tmin'].value_counts()
# Out:
# Next_Tmin
# 23.5    159
# 23.4    157
# 24.0    156
# 23.2    150
# 23.8    149
#        ...
# 13.6      1
# 14.6      1
# 13.9      1
# 15.2      1
# 12.9      1
# Name: count, Length: 157, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
#handeling null values
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df['station'].fillna(method='ffill',inplace=True)

# %%
df['Present_Tmax'].fillna(method='ffill',inplace=True)

# %%
df['Present_Tmin'].fillna(method='ffill',inplace=True)
df['LDAPS_RHmin'].fillna(method='ffill',inplace=True)
df['LDAPS_RHmax'].fillna(method='ffill',inplace=True)
df['LDAPS_Tmax_lapse'].fillna(method='ffill',inplace=True)
df['LDAPS_Tmin_lapse'].fillna(method='ffill',inplace=True)
df['LDAPS_WS'].fillna(method='ffill',inplace=True)
df['LDAPS_LH'].fillna(method='ffill',inplace=True)
df['LDAPS_CC1'].fillna(method='ffill',inplace=True)
df['LDAPS_CC2'].fillna(method='ffill',inplace=True)

# %%
df['LDAPS_CC3'].fillna(method='ffill',inplace=True)
df['LDAPS_CC4'].fillna(method='ffill',inplace=True)
df['LDAPS_PPT1'].fillna(method='ffill',inplace=True)
df['LDAPS_PPT2'].fillna(method='ffill',inplace=True)
df['LDAPS_PPT3'].fillna(method='ffill',inplace=True)
df['LDAPS_PPT4'].fillna(method='ffill',inplace=True)
df['Next_Tmax'].fillna(method='ffill',inplace=True)
df['Next_Tmin'].fillna(method='ffill',inplace=True)

# %%
df['Date'].fillna(value='Not available',inplace=True)

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0

# %%
print(f"Number of duplicate clumns: {df.duplicated().sum()}")
# Out:
# Number of duplicate clumns: 0

# %%
#converting datatypes
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
print(df['Date'].head())
print(df.dtypes)
# Out:
# 0   2013-06-30
# 1   2013-06-30
# 2   2013-06-30
# 3   2013-06-30
# 4   2013-06-30
# Name: Date, dtype: datetime64[ns]
# station                    float64
# Date                datetime64[ns]
# Present_Tmax               float64
# Present_Tmin               float64
# LDAPS_RHmin                float64
# LDAPS_RHmax                float64
# LDAPS_Tmax_lapse           float64
# LDAPS_Tmin_lapse           float64
# LDAPS_WS                   float64
# LDAPS_LH                   float64
# LDAPS_CC1                  float64
# LDAPS_CC2                  float64
# LDAPS_CC3                  float64
# LDAPS_CC4                  float64
# LDAPS_PPT1                 float64
# LDAPS_PPT2                 float64
# LDAPS_PPT3                 float64
# LDAPS_PPT4                 float64
# lat                        float64
# lon                        float64
# DEM                        float64
# Slope                      float64
# Solar radiation            float64
# ...

# %%
df.head()
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0 2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0 2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %% [markdown]
# data visualizing

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#line plot
plt.figure(figsize=(12,6))
plt.plot(df['Date'], df['Present_Tmax'], label='Present Tmax', alpha=0.7)
plt.plot(df['Date'], df['Next_Tmax'], label='Next Tmax', alpha=0.7)
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.title('Present vs Next Day Maximum Temperature Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
#histogram
plt.figure(figsize=(8,5))
sn.histplot(df['Next_Tmin'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Next Day Minimum Temperatures')
plt.xlabel('Next_Tmin (°C)')
plt.ylabel('Frequency')
plt.show()

# %%
#heatmap
plt.figure(figsize=(14,10))
sn.heatmap(df.corr(numeric_only=True), cmap='coolwarm', annot=True, fmt=".2f")
plt.title('Correlation Between Weather Features')
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10,6))
sn.scatterplot(data=df, x='lon', y='lat', hue='Next_Tmax', palette='coolwarm')
plt.title('Geographic Distribution of Next Day Tmax')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Next_Tmax')
plt.show()

# %%
#box plot
plt.figure(figsize=(14,6))
sn.boxplot(x='station', y='Next_Tmax', data=df)
plt.title('Next Day Tmax by Station')
plt.xlabel('Station')
plt.ylabel('Next Day Tmax (°C)')
plt.xticks(rotation=90)
plt.show()

# %%
#line plot
plt.figure(figsize=(14, 6))
plt.plot(df['Date'], df['Next_Tmax'], label='Next_Tmax (Max Temp)', color='orange')
plt.plot(df['Date'], df['Next_Tmin'], label='Next_Tmin (Min Temp)', color='steelblue')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.title('Next Day Maximum and Minimum Temperatures Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#histrogram
plt.figure(figsize=(10, 5))
sn.histplot(df['Next_Tmax'], bins=30, color='red', label='Next_Tmax', kde=True, alpha=0.6)
sn.histplot(df['Next_Tmin'], bins=30, color='blue', label='Next_Tmin', kde=True, alpha=0.6)
plt.title('Distribution of Next Day Max and Min Temperatures')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#scatter plot
plt.figure(figsize=(8, 6))
sn.scatterplot(x='Next_Tmin', y='Next_Tmax', data=df, alpha=0.5)
plt.title('Relationship Between Next Day Min and Max Temperatures')
plt.xlabel('Next_Tmin (°C)')
plt.ylabel('Next_Tmax (°C)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#  data preprocessing

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
      #feature engineering
#temperature range
df['Present_TempRange'] = df['Present_Tmax'] - df['Present_Tmin']
df['Next_TempRange'] = df['Next_Tmax'] - df['Next_Tmin']

# %%
#data-based feature
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['DayOfWeek'] = df['Date'].dt.dayofweek  # 0 = Monday

# %%
#encoding
df['station'] = df['station'].astype('category')
df['station_cat'] = df['station'].cat.codes

# %%
df.drop(columns=['station'], inplace=True)

# %% [markdown]
# modeling

# %%
# Split features and target
x = df.drop(columns=['Date', 'Next_Tmax', 'Next_Tmin'])
y = df[['Next_Tmax', 'Next_Tmin']]

# %%
# train the model
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# fit a model
base_model = RandomForestRegressor(n_estimators=100, random_state=42)
multi_model = MultiOutputRegressor(base_model)

multi_model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
#predict the model
y_pred = multi_model.predict(X_test)

# %%
# Split predictions
pred_tmax = y_pred[:, 0]
pred_tmin = y_pred[:, 1]

# %%
# True values
true_tmax = y_test['Next_Tmax'].values
true_tmin = y_test['Next_Tmin'].values

# %%
# Evaluation
print(" Next_Tmax Evaluation:")
print(f"MAE: {mean_absolute_error(true_tmax, pred_tmax):.2f} °C")
print(f"RMSE: {np.sqrt(mean_squared_error(true_tmax, pred_tmax)):.2f} °C")
print(f"R² Score: {r2_score(true_tmax, pred_tmax):.2f}")

print("\n Next_Tmin Evaluation:")
print(f"MAE: {mean_absolute_error(true_tmin, pred_tmin):.2f} °C")
print(f"RMSE: {np.sqrt(mean_squared_error(true_tmin, pred_tmin)):.2f} °C")
print(f"R² Score: {r2_score(true_tmin, pred_tmin):.2f}")
# Out:
#  Next_Tmax Evaluation:
# MAE: 0.53 °C
# RMSE: 0.69 °C
# R² Score: 0.95
#
#  Next_Tmin Evaluation:
# MAE: 0.52 °C
# RMSE: 0.69 °C
# R² Score: 0.92

# %%
# Feature importance
tmax_importances = pd.Series(multi_model.estimators_[0].feature_importances_, index=x.columns)
tmax_importances.sort_values().plot(kind='barh', figsize=(10, 6), color='blue')
plt.title("Feature Importance for Predicting Next_Tmax")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
tmin_importances = pd.Series(multi_model.estimators_[1].feature_importances_, index=x.columns)
tmin_importances.sort_values().plot(kind='barh', figsize=(10, 6), color='skyblue')
plt.title("Feature Importance for Predicting Next_Tmin")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()
